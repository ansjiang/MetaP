# %% [markdown]
# ## Cirrhosis disease prediction

# %%
import numpy as np
import pandas as pd 
import os

disease = "Cirrhosis" 
# feature_string = 'K_' or 'gi_'
def loadData(feature_string , label_string , label_dict) :
    #read file
    
    filename = "./data/abundance_" + disease + ".txt"  
    if os.path.isfile(filename) :
        rawdata = pd.read_csv(filename , sep = '\t' , index_col=0 , header=None) 
    else :
        print("FileNotFoundError: File {} does not exist".format(filename))
        exit()

    # select rows having feature index identifier string  
    X = rawdata.loc[rawdata.index.str.contains(feature_string, regex=False)].astype('float64')

    # get class labels
    Y = rawdata.loc[label_string] #'disease'
    Y = Y.replace(label_dict).astype('int')
     
    return X , Y 

# def prepare_data(config) :
feature_string = 'k__'
label_string = 'disease'
label_dict = {
    # Controls
    'n': 0,
    # Cirrhosis
    'cirrhosis': 1,
    # T2D and WT2D
    't2d': 1,
    # Obesity
    'leaness': 0, 'obesity': 1,
}

Raw_X_data , labels = loadData(feature_string , label_string , label_dict )
Raw_X_data = Raw_X_data.transpose() 
labels = labels.values
def filter_data(x , y , filter_thresh) :
    
    classes = np.unique(y) 
    index = x.index.values  

    num_counts = {} 
    for c in classes :
        sub_x = x[y == c]
        num_samples = len(sub_x) 
        # sub_x[sub_x > 0].count()  
        num_counts[str(c)] = sub_x[sub_x > 0].count() / float(num_samples)

    core = pd.DataFrame(index=index)
    for feature in x.columns.values:
        for c in classes : 
            if(num_counts[str(c)].loc[feature] >= filter_thresh) :
                #core[feature] = x[feature].copy()
                core = pd.concat([core , x[feature]] , axis=1)
                break 
    return core 

def get_feature_df(features):
    kingdom, phylum, cl, order, family, genus, species  = [], [], [], [], [], [], []
    for f in features:

        name = f.split("k__")[1].split("|p__")[0].replace(".","")
        if "_unclassified" in name:
            name = 'unclassified_' + name.split("_unclassified")[0]
        kingdom.append(name)

        if "p__" in f:
            name =f.split("p__")[1].split("|c__")[0].replace(".","")
            if "_unclassified" in name:
                name = 'unclassified_' + name.split("_unclassified")[0]
            if name != "":
                phylum.append(name)
            else:
                phylum.append("NA")
        else:
            phylum.append("NA")
            
        if "c__" in f:
            name = f.split("c__")[1].split("|o__")[0].replace(".","")
            if "_unclassified" in name:
                name = 'unclassified_' + name.split("_unclassified")[0]
            if name != "":
                cl.append(name)
            else:
                cl.append("NA")
        else:
            cl.append("NA")
            
        if "o__" in f:
            name = f.split("o__")[1].split("|f__")[0].replace(".","")
            if "_unclassified" in name:
                name = 'unclassified_' + name.split("_unclassified")[0]
            if name != "":
                order.append(name)
            else:
                order.append("NA")
        else:
            order.append("NA")
            
        if "f__" in f:
            name = f.split("f__")[1].split("|g__")[0].replace(".","")
            if "_unclassified" in name:
                name = 'unclassified_' + name.split("_unclassified")[0]
            if name != "":
                family.append(name)
            else:
                family.append("NA")
        else:
            family.append("NA")
            
        if "g__" in f:
            name = f.split("g__")[1].split("|s__")[0].replace(".","")
            if "_unclassified" in name:
                name = 'unclassified_' + name.split("_unclassified")[0]
            if name != "":
                genus.append(name)
            else:
                genus.append("NA")
        else:
            genus.append("NA")
            
        if "s__" in f:
            name = f.split("s__")[1]
            if "_unclassified" in name:
                name = 'unclassified_' + name.split("_unclassified")[0]
            if name != "":
                species.append(name)
            else:
                species.append("NA")
        else:
            species.append("NA")
            
    if len(species) == 0:
        d = {'kingdom': kingdom, 'phylum': phylum, 'class':cl,
            'order':order, 'family':family, 'genus':genus}
        feature_df = pd.DataFrame(data=d)
        feature_df.index = feature_df['genus']
    else:
        d = {'kingdom': kingdom, 'phylum': phylum, 'class':cl,
            'order':order, 'family':family, 'genus':genus, 'species': species}
        feature_df = pd.DataFrame(data=d)
        feature_df.index = feature_df['species']
    return feature_df
 
filter_X_data = filter_data(Raw_X_data , labels , 0.2)
features = list(filter_X_data.columns.values)
features_df = get_feature_df(features)  
print("samples are %d , Raw features are %d ..." % (Raw_X_data.shape[0] ,  Raw_X_data.shape[1]))  
print("filter data after samples are %d , filter Raw features are %d ..." % (filter_X_data.shape[0] ,  filter_X_data.shape[1]))
# Out:
# samples are 232 , Raw features are 542 ...
# filter data after samples are 232 , filter Raw features are 193 ...

# %%
from graph import Graph
import pickle
from joblib import Parallel, delayed
import multiprocessing
from copy import deepcopy

def generate_dense_maps(x, g, f, p=-1):
    id = multiprocessing.Process()._identity
    temp_g = deepcopy(g)
    temp_g.populate_graph(f, x)
    map = temp_g.get_dense_map()
    vector = temp_g.graph_vector_features()
    del(temp_g)
    return np.array(map)

print("Contsructing tree..")
g = Graph()
g.build_graph()
g.prune_graph(features_df)
print("Populating trees...")	 
results2 = Parallel(n_jobs=4)(delayed(generate_dense_maps)(x,g,features_df) for x in filter_X_data.values)
x_data_dense_maps = np.array(results2) 
filter_x_data = filter_X_data.values 
print(x_data_dense_maps.shape)
print(filter_x_data.shape)
# Out:
# Contsructing tree..
# Pruning Tree...
# Populating trees...
# (232, 5, 132)
# (232, 193)

# %%
from sklearn.metrics import roc_auc_score ,accuracy_score , matthews_corrcoef, precision_score, recall_score, f1_score
from torch.utils.data import Dataset , DataLoader
from sklearn.model_selection import StratifiedKFold 
from sklearn.preprocessing import MinMaxScaler
from new_Micro_Permutator import Meta_P  
import torch 
import shap

 
seed = 100
np.random.seed(seed)
np.random.shuffle(filter_x_data) 
np.random.seed(seed)
np.random.shuffle(x_data_dense_maps)  
np.random.seed(seed)
np.random.shuffle(labels)

cv_list = ["Run_" + "_CV_" + str(y) for y in range(10)]
MicroP_stat_df = pd.DataFrame(index=["AUC", "ACC" , "MCC", "Precision", "Recall", "F1" , "repeat_seed"], columns=cv_list) 
Shap_df_cv = pd.DataFrame(index=features_df.index , columns=cv_list)

# %%
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
skf_index = skf.split(x_data_dense_maps, labels) 
for j , idx in enumerate(skf_index) : 
    fold_num = "fold_%s" % str(j).zfill(2)
    print('#'*50 + ' %s ' % (fold_num) + '#'*50 )

    train_index, test_index = idx    
    train_x, test_x = x_data_dense_maps[train_index], x_data_dense_maps[test_index] 
    train_raw_x , test_raw_x = filter_x_data[train_index] , filter_x_data[test_index]
    train_y, test_y = labels[train_index], labels[test_index]
    
    class DatasetLoarder(Dataset) :
        def __init__(self , X_train , y_train) :
            self.len = X_train.shape[0]
            self.x_data = torch.from_numpy(X_train).type(torch.FloatTensor)
            self.y_data = torch.from_numpy(y_train).type(torch.LongTensor)
            
        def __getitem__(self , index) :
            return self.x_data[index] , self.y_data[index]

        def __len__(self) :
            return self.len 

    train_dataset  = DatasetLoarder(train_x , train_y)  
    train_loader = DataLoader(dataset=train_dataset , batch_size=32 , num_workers=0)  
    test_dataset = DatasetLoarder(test_x , test_y)
    test_loader = DataLoader(dataset=test_dataset , batch_size=32 , num_workers=0 )  
            
            
    def eval(model , test_loader): # test
        model.eval()
        true_label = [] 
        y_prob = []
        with torch.no_grad():

            for step , batch in enumerate(test_loader):
                x, label = batch
                val_output = model(x)
                true_label  = true_label + label.tolist() 
                y_prob = y_prob + val_output.tolist()
                
        y_prob = np.array(y_prob)
        true_label = np.array(true_label)
        return true_label , y_prob 

    def train(model , train_loader , test_loader , learn_rate , epoch ) :
        
        # loss function
        criterion = torch.nn.CrossEntropyLoss()
        # optimizer
        optimizer = torch.optim.Adam(model.parameters(), lr=learn_rate ) # 2e-4 
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5 , gamma=0.5)
        
        for i in range(epoch):
            model.train()
            # one epoch
            for step, batch in enumerate(train_loader):
                x, label = batch
                output = model(x)
                loss = criterion(output, label)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
            scheduler.step()
            # y_true , y_prob  = eval(model=model , test_loader=test_loader) 
            # y_pred = np.argmax(y_prob , axis=1)
            # #print("method = {}  test Epoch:{} ,   eval_acc:{} , eval_auc :{} ".format(method , i, round(accuracy_score(y_true, y_pred), 3) , round(roc_auc_score(y_true, y_prob, multi_class='ovo'), 3)))
            # print("method = {}  test Epoch:{} ,  eval_acc:{} ".format("method" , i, round(accuracy_score(y_true, y_pred), 3)))

                
    model = Meta_P(
        image_h= train_x.shape[1],
        image_w= train_x.shape[2],
        segments = 8,
        patch_h = train_x.shape[1] ,
        patch_w = 3 ,
        dim = 48 ,
        depth = 1,
        num_classes = 2 ,
        expansion_factor = 1, 
    )
    print("training........ Micro Permutator model ................. ")

    train(model  , train_loader , test_loader , learn_rate=5e-4 , epoch=20)
    
    y_true , y_prob  = eval(model=model , test_loader=test_loader) 
    y_pred = np.argmax(y_prob , axis=1)
    
    
    metrics = {   
        "ACC" : round(accuracy_score(y_true, y_pred), 3),
        "Recall" : round(recall_score(y_true, y_pred , average='weighted') , 3 ) ,
        "Precision" : round(precision_score(y_true, y_pred, average='weighted') , 3) ,
        "F1"    : round(f1_score(y_true, y_pred, average='weighted') , 3) , 
        "MCC" : round(matthews_corrcoef(y_true, y_pred), 3),
        "AUC" : round(roc_auc_score(y_true, y_prob[:, 1]) , 3) ,
        "method" : "Meta_P",
    } 
    
    print("MicroP  fold {} , metrics {}".format(j , metrics))

    MicroP_stat_df.loc["AUC"]["Run_" + "_CV_" + str(j)] = metrics["AUC"]
    MicroP_stat_df.loc["ACC"]["Run_" + "_CV_" + str(j)] = metrics["ACC"]
    MicroP_stat_df.loc["MCC"]["Run_" + "_CV_" + str(j)] = metrics["MCC"]
    MicroP_stat_df.loc["Precision"]["Run_" + "_CV_" + str(j)] =  metrics["Precision"]
    MicroP_stat_df.loc["Recall"]["Run_" + "_CV_" + str(j)]= metrics["Recall"]
    MicroP_stat_df.loc["F1"]["Run_" + "_CV_" + str(j)] =  metrics["F1"] 

    # explainer model
    
    model.eval() 
    def predict(input_data):
        X_data = []
        for x in input_data : 
            map = generate_dense_maps(x , g , features_df)
            X_data.append(map)
        X_data = np.array(X_data)
        output = model(torch.tensor(X_data).type(torch.FloatTensor)) 
        output_np = output.detach().numpy()
        return output_np
    
    # gmin = train_raw_x.min().min()
    # backgroud_data =  np.full(shape=(1, train_raw_x.shape[1]), fill_value = gmin)
    backgroud_data = shap.kmeans(train_raw_x, 2) 
    explainer = shap.KernelExplainer(predict, backgroud_data)
    shap_values = explainer.shap_values(test_raw_x)

    mean_shap_values = np.mean(shap_values[0], axis=0)  
    Shap_df_cv["Run_" + "_CV_" + str(j)] = mean_shap_values
    Shap_df_cv.to_csv('Shap_df_cv_Cirrhosis_0.csv')
    del(model) 
    
    #break
# Out:
# ################################################## fold_00 ##################################################
# training........ Micro Permutator model .................
# MicroP  fold 0 , metrics {'ACC': 0.875, 'Recall': 0.875, 'Precision': 0.9, 'F1': 0.873, 'MCC': 0.775, 'AUC': 0.979, 'method': 'Micro_P'}
#   0%|          | 0/24 [00:00<?, ?it/s]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   4%|▍         | 1/24 [09:33<3:39:45, 573.30s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   8%|▊         | 2/24 [19:22<3:33:34, 582.48s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  12%|█▎        | 3/24 [28:48<3:21:13, 574.91s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  17%|█▋        | 4/24 [38:26<3:12:06, 576.33s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  21%|██        | 5/24 [47:50<3:01:05, 571.87s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  25%|██▌       | 6/24 [57:18<2:51:10, 570.58s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  29%|██▉       | 7/24 [1:06:44<2:41:12, 568.96s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  33%|███▎      | 8/24 [1:16:10<2:31:28, 568.06s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  38%|███▊      | 9/24 [1:25:34<2:21:41, 566.80s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  42%|████▏     | 10/24 [1:35:00<2:12:13, 566.71s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  46%|████▌     | 11/24 [1:44:29<2:02:56, 567.40s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  50%|█████     | 12/24 [1:54:00<1:53:40, 568.39s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  54%|█████▍    | 13/24 [2:03:29<1:44:14, 568.62s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  58%|█████▊    | 14/24 [2:12:56<1:34:41, 568.16s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  62%|██████▎   | 15/24 [2:22:23<1:25:10, 567.81s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  67%|██████▋   | 16/24 [2:31:49<1:15:38, 567.27s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  71%|███████   | 17/24 [2:41:15<1:06:07, 566.79s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  75%|███████▌  | 18/24 [2:50:41<56:38, 566.50s/it]  The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  79%|███████▉  | 19/24 [3:00:07<47:11, 566.31s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  83%|████████▎ | 20/24 [3:09:35<37:47, 566.93s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  88%|████████▊ | 21/24 [3:19:03<28:21, 567.12s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  92%|█████████▏| 22/24 [3:28:29<18:53, 566.83s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  96%|█████████▌| 23/24 [3:37:55<09:26, 566.72s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# 100%|██████████| 24/24 [3:47:22<00:00, 568.44s/it]
# ################################################## fold_01 ##################################################
# training........ Micro Permutator model .................
# MicroP  fold 1 , metrics {'ACC': 0.875, 'Recall': 0.875, 'Precision': 0.878, 'F1': 0.875, 'MCC': 0.753, 'AUC': 0.938, 'method': 'Micro_P'}
#   0%|          | 0/24 [00:00<?, ?it/s]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   4%|▍         | 1/24 [09:28<3:37:52, 568.37s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   8%|▊         | 2/24 [18:54<3:27:49, 566.80s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  12%|█▎        | 3/24 [28:21<3:18:29, 567.14s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  17%|█▋        | 4/24 [37:47<3:08:53, 566.70s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  21%|██        | 5/24 [47:13<2:59:18, 566.22s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  25%|██▌       | 6/24 [56:38<2:49:50, 566.12s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  29%|██▉       | 7/24 [1:06:05<2:40:27, 566.30s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  33%|███▎      | 8/24 [1:15:35<2:31:19, 567.48s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  38%|███▊      | 9/24 [1:25:02<2:21:47, 567.15s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  42%|████▏     | 10/24 [1:34:28<2:12:16, 566.87s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  46%|████▌     | 11/24 [1:43:57<2:02:59, 567.67s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  50%|█████     | 12/24 [1:53:24<1:53:27, 567.28s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# ...
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  48%|████▊     | 11/23 [1:44:10<1:53:32, 567.71s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  52%|█████▏    | 12/23 [1:53:38<1:44:06, 567.87s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  57%|█████▋    | 13/23 [2:03:08<1:34:46, 568.66s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  61%|██████    | 14/23 [2:12:36<1:25:14, 568.30s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  65%|██████▌   | 15/23 [2:22:03<1:15:42, 567.85s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  70%|██████▉   | 16/23 [2:31:29<1:06:12, 567.49s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  74%|███████▍  | 17/23 [2:40:57<56:44, 567.48s/it]  The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  78%|███████▊  | 18/23 [2:50:23<47:15, 567.01s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  83%|████████▎ | 19/23 [2:59:49<37:46, 566.73s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  87%|████████▋ | 20/23 [3:09:21<28:24, 568.23s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  91%|█████████▏| 21/23 [3:19:00<19:03, 571.72s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#  96%|█████████▌| 22/23 [3:28:41<09:34, 574.47s/it]The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLarsIC())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
# 100%|██████████| 23/23 [3:38:21<00:00, 569.63s/it]

# %%
features_name = features_df.index.tolist()
for idx in range(len(features_name)) : 
    if features_name[idx] == 'NA' :  
        features_name[idx] = features_df.iloc[idx]['genus']
    if 'unclassified' in features_name[idx] :
        features_name[idx] = features_name[idx][13:]  + ' spp.'

Shap_df_cv = pd.read_csv('Shap_df_cv_Cirrhosis_mean_10.csv' , index_col=0)

 
# mean_shap_values = Shap_df_cv.mean(axis=1) 
SHAP_mean_df = pd.DataFrame(Shap_df_cv.mean(axis=1 , numeric_only=True).abs(), columns=['SHAP'])

 
label_dfy = pd.DataFrame(labels, columns=['group'])
tmp_data_df = filter_X_data.join(label_dfy)
abundance_mean_df = tmp_data_df.groupby('group').mean().transpose()
abundance_mean_df.columns = ["health" , "disease"]
# print(features_name)
# print(abundance_mean_df.index)
# print(Shap_df_cv.index)
abundance_mean_df.index = features_name
SHAP_mean_df.index = features_name  
SHAP_Abundance_mean_df = SHAP_mean_df.join(abundance_mean_df) 
plot_data_df = SHAP_Abundance_mean_df.sort_values(by='SHAP', ascending=False)
# plot_data_df = data_sort_df[0:20]
print(plot_data_df.head(20))
# Out:
#                                            SHAP    health   disease
# Veillonella spp.                       0.043570  0.241058  4.270896
# Streptococcus_anginosus                0.041613  0.010014  0.212882
# Lactobacillus_salivarius               0.040546  0.035808  1.095688
# Streptococcus_infantarius              0.037941  0.006058  0.133302
# Veillonella_dispar                     0.025951  0.016764  0.614258
# Streptococcus_mutans                   0.023659  0.000034  0.020875
# Streptococcus_parasanguinis            0.019926  0.034029  0.775711
# Lactobacillus_fermentum                0.016433  0.002618  0.109745
# Bifidobacterium_dentium                0.016346  0.003900  0.168830
# Streptococcus_cristatus                0.016223  0.000149  0.009242
# Lactobacillus_mucosae                  0.015359  0.006082  0.304462
# Streptococcus_mitis_oralis_pneumoniae  0.015221  0.001631  0.030806
# Megasphaera_micronuciformis            0.014854  0.003398  0.216589
# Coprobacillus spp.                     0.014490  0.029024  0.127586
# Actinomyces_odontolyticus              0.014061  0.000206  0.005312
# Megamonas spp.                         0.013186  1.329988  0.842174
# Veillonella_atypica                    0.012663  0.050860  0.540265
# Adlercreutzia_equolifaciens            0.011820  0.040759  0.005962
# Clostridium_hathewayi                  0.010704  0.029141  0.347548
# Streptococcus_sanguinis                0.009899  0.000531  0.011711

# %%
 
mean_shap_values = Shap_df_cv.mean(axis=1)
 
feature_indices = range(len(mean_shap_values))
feature_names = features_df.index   

 
feature_importance = {feature_names[i]: mean_shap_values[i] for i in feature_indices}

 
sorted_feature_importance = sorted(feature_importance.items(), key=lambda x: abs(x[1]), reverse=True)

 
for feature, importance in sorted_feature_importance:
    print(f"{feature}: {importance}")
# Out:
# Adlercreutzia_equolifaciens: -0.24823499444763308
# unclassified_Olsenella: 0.2228137144831697
# Streptococcus_anginosus: 0.21537477260063093
# Streptococcus_sanguinis: 0.1782053695930611
# unclassified_Megasphaera: 0.15968289031501048
# Gordonibacter_pamelaeae: 0.1459563454487867
# Streptococcus_salivarius: -0.14269718783354923
# Bifidobacterium_adolescentis: 0.12532985297803334
# Clostridium_nexile: -0.11347240887613894
# Acidaminococcus_fermentans: 0.11009630706856839
# unclassified_Megamonas: 0.10936227633646839
# Eubacterium_ventriosum: 0.10282316382886272
# Alistipes_putredinis: -0.10024184931333621
# Bacteroides_stercoris: -0.09874777899915833
# Streptococcus_infantis: 0.09430712250910218
# Eubacterium_dolichum: -0.09323826415169527
# Granulicatella_adiacens: 0.0804628523367482
# Streptococcus_australis: -0.07895189995385754
# Roseburia_intestinalis: -0.07717200688820001
# Bifidobacterium_bifidum: 0.07058404992993533
# Streptococcus_vestibularis: 0.06862108167695616
# Fusobacterium_mortiferum: 0.0680590782237307
# unclassified_Mitsuokella: 0.06722775579138342
# Enterococcus_faecalis: 0.06590506564364093
# unclassified_Acidaminococcus: 0.06228828963832579
# Ruminococcus_gnavus: -0.061551780227070356
# unclassified_Peptostreptococcaceae_noname: -0.06138494680337742
# unclassified_Veillonella: -0.05993538768562273
# Megamonas_rupellensis: -0.059515698924045596
# Megasphaera_elsdenii: -0.056247039068324914
# Lactobacillus_salivarius: 0.05619974568004644
# Streptococcus_parasanguinis: -0.05554943929422043
# Akkermansia_muciniphila: 0.055105895284736674
# Holdemania_filiformis: 0.05501546399448278
# unclassified_Holdemania: 0.054158818474726006
# Parabacteroides_merdae: -0.04603812469050723
# Ruminococcus_bromii: 0.044144634704327154
# unclassified_Parabacteroides: 0.042439198970011666
# Parabacteroides_johnsonii: 0.04221150470100696
# Megamonas_funiformis: 0.041295489532820896
# Actinomyces_graevenitzii: -0.040992191670444156
# Megasphaera_micronuciformis: 0.038656538729425954
# Eubacterium_eligens: 0.03817597452886264
# Collinsella_tanakaei: -0.037894705697654955
# Bacteroides_coprocola: 0.03770938334455254
# Lactobacillus_amylovorus: 0.03751722792779989
# unclassified_Granulicatella: 0.03747181870188415
# Bifidobacterium_dentium: -0.03719262105990959
# Parabacteroides_distasonis: 0.03705411856232067
# Eubacterium_biforme: -0.03686676068510442
# Coprococcus_comes: -0.03609303258070929
# Escherichia_coli: 0.03357769208616612
# Prevotella_stercorea: -0.031768411697310345
# Actinomyces_odontolyticus: 0.030883690157219965
# Solobacterium_moorei: 0.029766234749180907
# Acidaminococcus_intestini: -0.0294199857954505
# Clostridium_sp_L2_50: -0.02914993644351188
# Pyramidobacter_piscolens: 0.028610450405361858
# Prevotella_copri: -0.028112433606095548
# Barnesiella_intestinihominis: 0.02788693934357976
# Eubacterium_siraeum: 0.02694103699399772
# Rothia_mucilaginosa: -0.026662460005563653
# Clostridium_ramosum: 0.025212689940117508
# Clostridium_hathewayi: 0.02505109175955708
# unclassified_Subdoligranulum: -0.02388971836297637
# Faecalibacterium_prausnitzii: -0.023708798854496265
# Streptococcus_infantarius: 0.02357548444954178
# Erysipelotrichaceae_bacterium_3_1_53: 0.023432956558101722
# Fusobacterium_varium: 0.02310975763898951
# Fusobacterium_ulcerans: 0.02308205793983317
# Bacteroides_dorei: 0.02216060361919025
# Veillonella_dispar: -0.021776617545696722
# unclassified_Oscillibacter: -0.02171062848108698
# Eggerthella_lenta: 0.021515754244368787
# Parabacteroides_goldsteinii: 0.021460662071496706
# Clostridium_bartlettii: -0.02045369707152256
# Bifidobacterium_longum: -0.01930782609220346
# Ruminococcus_sp_5_1_39BFAA: -0.01881018865727893
# Ruminococcus_torques: 0.01868489533502722
# Eubacterium_hallii: 0.017993873629295346
# Ruminococcus_callidus: -0.017758933695206154
# Abiotrophia_defectiva: -0.017629666197086193
# Bacteroides_ovatus: 0.017377939429845852
# Anaerotruncus_colihominis: -0.0172874838880261
# Bacteroides_uniformis: 0.017051517598527
# Coriobacteriaceae_bacterium_phI: 0.016366685391556807
# Lactobacillus_mucosae: -0.016182258205533574
# Paraprevotella_clara: -0.01587274113870061
# Bacteroides_eggerthii: 0.015124834154335118
# Lachnospiraceae_bacterium_1_4_56FAA: 0.015068722499037911
# Bifidobacterium_pseudocatenulatum: 0.01436456815822389
# Streptococcus_gordonii: 0.013860117627698329
# Ruminococcus_lactaris: -0.013857230730667185
# Veillonella_parvula: 0.01377327899622336
# Coprobacter_fastidiosus: 0.013745480230743118
# Megamonas_hypermegale: 0.01267871992138577
# Atopobium_parvulum: 0.012178091362830212
# Clostridium_bolteae: 0.012011392270700048
# Bacteroidales_bacterium_ph8: -0.011510973990769731
# Collinsella_aerofaciens: 0.011217812270655537
# Clostridiales_bacterium_1_7_47FAA: 0.011057659887086149
# Roseburia_hominis: -0.010362039528316717
# Ruminococcus_obeum: 0.01018370978313512
# Gemella_sanguinis: -0.010080768661952191
# Dialister_invisus: 0.00985240173869412
# Anaerostipes_hadrus: -0.009814609359892777
# unclassified_Odoribacter: -0.009581665139026262
# Eubacterium_rectale: -0.009509852070257938
# unclassified_Bilophila: 0.009501297065728095
# Erysipelotrichaceae_bacterium_21_3: 0.009385960106625686
# Candidatus_Zinderia_insecticola: 0.008923695839245016
# Bacteroides_xylanisolvens: 0.0089024723196107
# Lachnospiraceae_bacterium_2_1_58FAA: -0.008566795722107966
# Alistipes_shahii: -0.008429832043597468
# Bacteroides_coprophilus: 0.008316551822053066
# Bacteroides_fragilis: -0.007977468247197708
# Bacteroides_clarus: 0.007951702821803495
# Bacteroides_plebeius: -0.007725614424720232
# Bacteroides_oleiciplenus: -0.007679831320340912
# Haemophilus_parainfluenzae: -0.007561251917697864
# Methanobrevibacter_smithii: -0.007456936584270688
# Alistipes_senegalensis: -0.007367923470640978
# Bacteroides_intestinalis: 0.007304047971092145
# unclassified_Comamonas: 0.0072848074123664985
# Veillonella_atypica: 0.007118438924968246
# Dorea_longicatena: -0.006618744713942762
# Lachnospiraceae_bacterium_5_1_57FAA: 0.006612362857625204
# Roseburia_inulinivorans: -0.006599112782280277
# unclassified_Eggerthella: 0.006557639416967866
# Clostridium_leptum: 0.0063850143239124885
# Streptococcus_mutans: 0.006184310801655149
# Sutterella_wadsworthensis: -0.006158836444440669
# unclassified_Roseburia: -0.0056942505867745765
# Bacteroides_salyersiae: 0.005602474676518546
# Bacteroides_finegoldii: 0.005582639744261736
# Lachnospiraceae_bacterium_5_1_63FAA: -0.0055651253768737915
# Odoribacter_splanchnicus: 0.0054892533803523325
# Peptostreptococcus_stomatis: 0.005428981593814813
# Erysipelotrichaceae_bacterium_6_1_45: 0.00521599133357461
# Clostridium_scindens: 0.005201996443038599
# Bacteroides_cellulosilyticus: 0.005158855858701168
# Bacteroides_thetaiotaomicron: 0.005048017069552671
# Paraprevotella_xylaniphila: 0.004932923198281815
# Eubacterium_sp_3_1_31: 0.004723046670176395
# unclassified_Anaerotruncus: 0.004668798670762794
# Eubacterium_limosum: 0.004556489511575203
# Bacteroides_nordii: -0.004495087129589764
# Clostridium_sp_ATCC_BAA_442: -0.004332056060717113
# Bacteroides_vulgatus: -0.003996729353280573
# Butyricimonas_synergistica: 0.0038683287772161216
# unclassified_Methanobrevibacter: -0.0038366934053422896
# Clostridium_innocuum: -0.003636714646576789
# unclassified_Collinsella: -0.0036118242620801193
# Clostridium_perfringens: 0.003564126792772802
# Pseudoflavonifractor_capillosus: 0.003348359957848607
# Desulfovibrio_desulfuricans: 0.0033188290228392398
# Burkholderiales_bacterium_1_1_47: 0.003298134180339626
# unclassified_Anaerostipes: -0.0032637296821749584
# Alistipes_finegoldii: -0.0032157092238868264
# Enterobacter_cloacae: 0.0031002911722122135
# unclassified_Gemella: -0.003051544764133378
# Oxalobacter_formigenes: 0.002743985471413192
# unclassified_Klebsiella: -0.0026606212461224577
# Ruminococcus_albus: 0.00260265056209992
# Prevotella_disiens: 0.002594959893549381
# Bacteroides_caccae: 0.002530898031160127
# Oscillibacter_sp_KLE_1745: 0.002469857498747573
# Clostridiaceae_bacterium_JC118: 0.0024369913224898537
# unclassified_Paraprevotella: 0.002367458578834407
# unclassified_Escherichia: 0.002363046328109448
# candidate_division_TM7_single_cell_isolate_TM7c: -0.0023474911688650124
# Alistipes_onderdonkii: -0.002136666855802438
# Lachnospiraceae_bacterium_8_1_57FAA: 0.0020769730060493036
# NA: -0.0020581424369567336
# Fusobacterium_nucleatum: -0.0020502077356450016
# Dorea_formicigenerans: -0.0020028642293973818
# Lachnospiraceae_bacterium_3_1_46FAA: -0.0019755085529612653
# candidate_division_TM7_single_cell_isolate_TM7b: -0.0019728259654537283
# Coprococcus_catus: 0.00195101812483435
# Flavonifractor_plautii: -0.001912711806115432
# Parasutterella_excrementihominis: -0.0019015823574368707
# Lachnospiraceae_bacterium_6_1_63FAA: -0.0018548121409315832
# unclassified_Coprobacillus: 0.0018405417027846371
# Clostridium_clostridioforme: 0.0018305669603530202
# Bacteroides_sp_2_1_22: -0.001754667843502167
# Alistipes_sp_AP11: 0.0016352644650574483
# Phascolarctobacterium_succinatutens: -0.0016208335100391987
# unclassified_Butyrivibrio: 0.0014834677404960302
# unclassified_Alistipes: 0.0012559941439280742
# Erysipelotrichaceae_bacterium_2_2_44A: -0.0012195210807960848
# Gemella_morbillorum: 0.001211953139913291
# Citrobacter_freundii: -0.001189280481227095
# Blautia_producta: -0.0011764005212175355
# Klebsiella_pneumoniae: -0.0011719707642598855
# Lachnospiraceae_bacterium_9_1_43BFAA: -0.0010991965838784293
# unclassified_Actinobacillus: 0.0010509327157656179
# Lachnospiraceae_bacterium_7_1_58FAA: 0.0010434813620997518
# Streptococcus_mitis_oralis_pneumoniae: -0.0008164974974147338
# Lachnospiraceae_bacterium_1_1_57FAA: -0.0008026555439857169
# Desulfovibrio_piger: -0.0007796073004457116
# Clostridium_asparagiforme: -0.0007696753667083311
# unclassified_Dorea: 0.0007263615952601971
# Alistipes_indistinctus: 0.0006920337346042896
# Clostridium_symbiosum: -0.0006516081767068416
# Clostridium_citroniae: -0.0006356215194065523
# Lachnospiraceae_bacterium_3_1_57FAA_CT1: -0.0005835835030775448
# Subdoligranulum_variabile: 0.0005016836449331732
# unclassified_Cellulophaga: -0.0004609979727781973
# Bifidobacterium_breve: 0.00045417998443079977
# Eubacterium_ramulus: -0.0003953390490406749
# unclassified_Pantoea: 0.00038961416513910935
# Ruminococcaceae_bacterium_D16: 0.0002632126888950845
# Ruminococcus_flavefaciens: 0.00025841198752270256
# Prevotella_bivia: 0.0001937246914734403
# Bacteroides_faecis: -0.00017826428849563344
# Subdoligranulum_sp_4_3_54A2FAA: -1.3787192634335046e-05
# Bacteroides_massiliensis: 0.0
# unclassified_Peptostreptococcus: 0.0
# Bilophila_wadsworthia: 0.0
# unclassified_Citrobacter: 0.0
# unclassified_Deinococcus: 0.0
# Shigella_flexneri: 0.0
